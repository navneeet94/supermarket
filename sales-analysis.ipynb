# %% [markdown]
# # IMPORT LIBRARIES

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy

# %% [markdown]
# # SETTING GLOBAL TRUE FALSE SHORT NAME

# %%
T = True
F = False

# %% [markdown]
# # LOADING AND SETTING DATASET

# %%
data_set = r'./SuperBazar.xls'
df = pd.read_excel(data_set)
df
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 1          2  CA-2017-152156 2017-11-08 2017-11-11    Second Class
# 2          3  CA-2017-138688 2017-06-12 2017-06-16    Second Class
# 3          4  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# 4          5  US-2016-108966 2016-10-11 2016-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2015-110422 2015-01-21 2015-01-23    Second Class
# 9990    9991  CA-2018-121258 2018-02-26 2018-03-03  Standard Class
# 9991    9992  CA-2018-121258 2018-02-26 2018-03-03  Standard Class
# 9992    9993  CA-2018-121258 2018-02-26 2018-03-03  Standard Class
# 9993    9994  CA-2018-119914 2018-05-04 2018-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %% [markdown]
# # GETTING INFORMATION OF DF COLUMNS

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9983 non-null   float64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# # describing data in df

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9983.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55245.233297    229.858001     3.789574     0.156203
# std    2885.163629  32038.715955    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  57103.000000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# # DROPPING UNWANTED COLUMNS

# %%
df.drop(['Row ID','Order ID','Customer ID','Product ID'],axis=1,inplace=T)
df
# Out:
#      Order Date  Ship Date       Ship Mode     Customer Name    Segment  \
# 0    2017-11-08 2017-11-11    Second Class       Claire Gute   Consumer
# 1    2017-11-08 2017-11-11    Second Class       Claire Gute   Consumer
# 2    2017-06-12 2017-06-16    Second Class   Darrin Van Huff  Corporate
# 3    2016-10-11 2016-10-18  Standard Class    Sean O'Donnell   Consumer
# 4    2016-10-11 2016-10-18  Standard Class    Sean O'Donnell   Consumer
# ...         ...        ...             ...               ...        ...
# 9989 2015-01-21 2015-01-23    Second Class  Tom Boeckenhauer   Consumer
# 9990 2018-02-26 2018-03-03  Standard Class       Dave Brooks   Consumer
# 9991 2018-02-26 2018-03-03  Standard Class       Dave Brooks   Consumer
# 9992 2018-02-26 2018-03-03  Standard Class       Dave Brooks   Consumer
# 9993 2018-05-04 2018-05-09    Second Class      Chris Cortes   Consumer
#
#             Country             City       State  Postal Code Region  \
# ...

# %% [markdown]
# # GETTING & DROPING NULL DATA

# %%
df.isnull().sum()
# Out:
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# dtype: int64

# %%
df.dropna(inplace=T)

# %% [markdown]
# # GETTING & DROPPING DUPLICATE COLUMNS

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=T)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
plt.plot(df['City'],df['Sales']);

# %%
sns.lineplot(df['City'],df['Sales']);
# Out:
# C:\Users\navne\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# # PLOT SALES BY CITY

# %%
city_obj = df.groupby(by="City")

# %%
city_df = city_obj.first()

# %%
city_obj.get_group('York')
# Out:
#      Order Date  Ship Date       Ship Mode  Customer Name    Segment  \
# 2145 2017-06-25 2017-06-29  Standard Class  Theresa Swint  Corporate
# 2146 2017-06-25 2017-06-29  Standard Class  Theresa Swint  Corporate
# 2147 2017-06-25 2017-06-29  Standard Class  Theresa Swint  Corporate
# 8474 2018-04-09 2018-04-14  Standard Class    Noah Childs  Corporate
# 8475 2018-04-09 2018-04-14  Standard Class    Noah Childs  Corporate
#
#             Country  City         State  Postal Code Region         Category  \
# 2145  United States  York  Pennsylvania      17403.0   East        Furniture
# 2146  United States  York  Pennsylvania      17403.0   East  Office Supplies
# 2147  United States  York  Pennsylvania      17403.0   East  Office Supplies
# 8474  United States  York  Pennsylvania      17403.0   East  Office Supplies
# 8475  United States  York  Pennsylvania      17403.0   East  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# ...

# %%
city_names = city_df.index.tolist()
city_names
# Out:
# ['Aberdeen',
#  'Abilene',
#  'Akron',
#  'Albuquerque',
#  'Alexandria',
#  'Allen',
#  'Allentown',
#  'Altoona',
#  'Amarillo',
#  'Anaheim',
#  'Andover',
#  'Ann Arbor',
#  'Antioch',
#  'Apopka',
#  'Apple Valley',
#  'Appleton',
#  'Arlington',
#  'Arlington Heights',
#  'Arvada',
#  'Asheville',
#  'Athens',
#  'Atlanta',
#  'Atlantic City',
#  'Auburn',
#  'Aurora',
#  'Austin',
#  'Avondale',
#  'Bakersfield',
#  'Baltimore',
#  'Bangor',
#  'Bartlett',
#  'Bayonne',
#  'Baytown',
#  'Beaumont',
#  'Bedford',
#  'Belleville',
#  'Bellevue',
#  'Bellingham',
#  'Bethlehem',
#  'Beverly',
#  'Billings',
#  'Bloomington',
#  'Boca Raton',
#  'Boise',
#  'Bolingbrook',
#  'Bossier City',
#  'Bowling Green',
#  'Boynton Beach',
#  'Bozeman',
#  'Brentwood',
#  'Bridgeton',
#  'Bristol',
#  'Broken Arrow',
#  'Broomfield',
#  'Brownsville',
#  'Bryan',
#  'Buffalo',
#  'Buffalo Grove',
#  'Bullhead City',
#  'Burbank',
#  'Burlington',
#  'Caldwell',
#  'Camarillo',
# ...

# %%
city_dict = {"city":[],"sales":[]}
for i in city_names:
    print(i)    
    city_dict["city"].append(i)
   
    # sales sum
    unique_city_sales = city_obj.get_group(i)['Sales'].values.sum()
    print(unique_city_sales)
    city_dict["sales"].append(unique_city_sales)
    
    print('---------------------------------------')
# Out:
# Aberdeen
# 25.5
# ---------------------------------------
# Abilene
# 1.3919999999999997
# ---------------------------------------
# Akron
# 2729.9860000000003
# ---------------------------------------
# Albuquerque
# 2220.1600000000003
# ---------------------------------------
# Alexandria
# 5519.57
# ---------------------------------------
# Allen
# 290.20599999999996
# ---------------------------------------
# Allentown
# 853.252
# ---------------------------------------
# Altoona
# 20.451
# ---------------------------------------
# Amarillo
# 3773.0628
# ---------------------------------------
# Anaheim
# 7986.87
# ---------------------------------------
# Andover
# 435.85
# ---------------------------------------
# Ann Arbor
# 889.2729999999999
# ---------------------------------------
# Antioch
# 19.44
# ---------------------------------------
# Apopka
# 904.5540000000002
# ---------------------------------------
# Apple Valley
# 2053.021
# ...

# %%
city_sales_df = pd.DataFrame(city_dict)
city_sales_df
# Out:
#             city     sales
# 0       Aberdeen    25.500
# 1        Abilene     1.392
# 2          Akron  2729.986
# 3    Albuquerque  2220.160
# 4     Alexandria  5519.570
# ..           ...       ...
# 526   Woonsocket   195.550
# 527      Yonkers  7657.666
# 528         York   817.978
# 529      Yucaipa    50.800
# 530         Yuma   840.865
#
# [531 rows x 2 columns]

# %%
city_sales_df[(city_sales_df['sales'] >= 30000)]
# Out:
#               city        sales
# 80         Chicago   48539.5410
# 94        Columbus   38424.8710
# 123        Detroit   42446.9440
# 207        Houston   64504.7604
# 216   Jacksonville   44713.1830
# 266    Los Angeles  175851.3410
# 329  New York City  256368.1610
# 374   Philadelphia  109077.0130
# 437      San Diego   47521.0290
# 438  San Francisco  112669.0920
# 452        Seattle  119540.7420
# 464    Springfield   43054.3420

# %%
plt.figure(figsize=(800,50))
sns.barplot(x=city_sales_df['city'],y=city_sales_df['sales']);

# %% [markdown]
# # PLOT WITH ATLEAST GREATER THAN THAT NUMBER CITY SALES

# %%
at_least_val = int(input("Enter number for greater than this number :- "))
city_at_least_df = city_sales_df[(city_sales_df['sales'] >= at_least_val)]
plt.figure(figsize=(20,5))
sns.barplot(x=city_at_least_df['city'],y=city_at_least_df['sales']);
# Out:
# Enter number for greater than this number :- 100000

# %% [markdown]
# # getting which sub category mostly sold in new york

# %%
new_york = city_obj.get_group('New York City')
new_york
# Out:
#      Order Date  Ship Date       Ship Mode      Customer Name      Segment  \
# 53   2017-12-11 2017-12-17  Standard Class     Janet Molinari    Corporate
# 54   2017-12-11 2017-12-17  Standard Class     Janet Molinari    Corporate
# 70   2017-09-18 2017-09-23  Standard Class  Henry MacAllister     Consumer
# 96   2018-11-09 2018-11-11    Second Class     Parhena Norris  Home Office
# 110  2018-12-25 2018-12-30  Standard Class      Cynthia Voltz    Corporate
# ...         ...        ...             ...                ...          ...
# 9926 2016-03-20 2016-03-23     First Class      Dave Hallsten    Corporate
# 9927 2016-03-20 2016-03-23     First Class      Dave Hallsten    Corporate
# 9938 2017-12-12 2017-12-17  Standard Class       Noel Staavos    Corporate
# 9939 2017-12-12 2017-12-17  Standard Class       Noel Staavos    Corporate
# 9940 2017-12-12 2017-12-17  Standard Class       Noel Staavos    Corporate
#
#             Country           City     State  Postal Code Region  \
# ...

# %%
new_york_cat = round(new_york['Category'].value_counts() / new_york.shape[0] * 100,2)
new_york_cat
# Out:
# Office Supplies    60.33
# Furniture          20.98
# Technology         18.69
# Name: Category, dtype: float64

# %%
plt.pie(new_york_cat.values,labels=new_york_cat.index,autopct="%0.2f");

# %%
new_york
# Out:
#      Order Date  Ship Date       Ship Mode      Customer Name      Segment  \
# 53   2017-12-11 2017-12-17  Standard Class     Janet Molinari    Corporate
# 54   2017-12-11 2017-12-17  Standard Class     Janet Molinari    Corporate
# 70   2017-09-18 2017-09-23  Standard Class  Henry MacAllister     Consumer
# 96   2018-11-09 2018-11-11    Second Class     Parhena Norris  Home Office
# 110  2018-12-25 2018-12-30  Standard Class      Cynthia Voltz    Corporate
# ...         ...        ...             ...                ...          ...
# 9926 2016-03-20 2016-03-23     First Class      Dave Hallsten    Corporate
# 9927 2016-03-20 2016-03-23     First Class      Dave Hallsten    Corporate
# 9938 2017-12-12 2017-12-17  Standard Class       Noel Staavos    Corporate
# 9939 2017-12-12 2017-12-17  Standard Class       Noel Staavos    Corporate
# 9940 2017-12-12 2017-12-17  Standard Class       Noel Staavos    Corporate
#
#             Country           City     State  Postal Code Region  \
# ...

# %%
newyork_subcat_df = pd.pivot_table(data=new_york,columns='Sub-Category',values="Sales",aggfunc="sum")
newyork_subcat_df
# Out:
# Sub-Category  Accessories  Appliances      Art    Binders  Bookcases  \
# Sales            17105.91    12294.54  2139.28  24567.696  17019.032
#
# Sub-Category     Chairs    Copiers  Envelopes  Fasteners  Furnishings  \
# Sales         40149.693  16719.856    1263.54     213.66      7558.23
#
# Sub-Category   Labels  Machines    Paper    Phones   Storage  Supplies  \
# Sales         1042.72  37531.21  6876.76  37959.13  21358.72   1604.09
#
# Sub-Category     Tables
# Sales         10964.094

# %%
plt.figure(figsize=(20,5))
sns.barplot(x=newyork_subcat_df.keys().tolist(),y=newyork_subcat_df.iloc[0].values);

# %%
print(f"max sub category saled => {newyork_subcat_df.iloc[0].idxmax()} ({newyork_subcat_df.iloc[0].values.max()})")
# Out:
# max sub category saled => Chairs (40149.693)

# %%
newyork_prod_sales_df = pd.pivot_table(data=new_york,columns='Product Name',values="Sales",aggfunc="sum")
newyork_prod_sales_df
# Out:
# Product Name  #10 Gummed Flap White Envelopes, 100/Box  \
# Sales                                            24.78
#
# Product Name  #10 White Business Envelopes,4 1/8 x 9 1/2  \
# Sales                                              47.01
#
# Product Name  #10- 4 1/8" x 9 1/2" Recycled Envelopes  \
# Sales                                           17.48
#
# Product Name  #10-4 1/8" x 9 1/2" Premium Diagonal Seam Envelopes  \
# Sales                                                     62.96
#
# Product Name  1.7 Cubic Foot Compact "Cube" Office Refrigerators  \
# Sales                                                   1248.96
#
# Product Name  3-ring staple pack  \
# Sales                     10.528
#
# Product Name  3D Systems Cube Printer, 2nd Generation, Magenta  \
# Sales                                                  5199.96
#
# Product Name  3M Organizer Strips  4009 Highlighters by Sanford  \
# Sales                       47.52                          19.9
#
# ...

# %%
plt.figure(figsize=(20,900))
sns.barplot(x=newyork_prod_sales_df.iloc[0].values,y= newyork_prod_sales_df.keys().tolist());

# %%
print(f"which product is mostly saled => {newyork_prod_sales_df.iloc[0].idxmax()} ({newyork_prod_sales_df.iloc[0].values.max()})")
# Out:
# which product is mostly saled => Canon imageCLASS 2200 Advanced Copier (11199.968)

# %% [markdown]
# # Getting Which top 5 products is mostly sold in per sub category

# %%
new_your_subcate_group = new_york.groupby(by="Sub-Category")

# %%
sub_cat_list = new_your_subcate_group.first().index.tolist()
sub_cat_list
# Out:
# ['Accessories',
#  'Appliances',
#  'Art',
#  'Binders',
#  'Bookcases',
#  'Chairs',
#  'Copiers',
#  'Envelopes',
#  'Fasteners',
#  'Furnishings',
#  'Labels',
#  'Machines',
#  'Paper',
#  'Phones',
#  'Storage',
#  'Supplies',
#  'Tables']

# %%
for i in sub_cat_list:
    print(i)
    sucat_df = new_your_subcate_group.get_group(i)
    sucat_df_prod = pd.pivot_table(data=sucat_df,columns="Product Name",values="Sales",aggfunc="sum")
    print(sucat_df_prod)
    print('-----------------------------------------------------------------------------------------------------------')
# Out:
# Accessories
# Product Name  AmazonBasics 3-Button USB Wired Mouse  \
# Sales                                         20.97
#
# Product Name  Belkin F8E887 USB Wired Ergonomic Keyboard  \
# Sales                                              89.97
#
# Product Name  Belkin QODE FastFit Bluetooth Keyboard  \
# Sales                                          247.8
#
# Product Name  Case Logic 2.4GHz Wireless Keyboard  \
# Sales                                       99.98
#
# Product Name  Dell Slim USB Multimedia Keyboard  \
# Sales                                      50.0
#
# Product Name  Enermax Acrylux Wireless Keyboard  Enermax Aurora Lite Keyboard  \
# Sales                                      99.6                         937.8
#
# Product Name  Imation Bio 8GB USB Flash Drive Imation Corp  \
# Sales                                               166.24
#
# Product Name  Imation 32GB Pocket Pro USB 3.0 Flash Drive - 32 GB - Black - 1 P ...  \
# ...
